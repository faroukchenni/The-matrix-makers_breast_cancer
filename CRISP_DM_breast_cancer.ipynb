# %% [markdown]
#  CRISP-DM Project: Breast-cancer Detection

# %% [markdown]
# ****Phase 1: Business Understanding****
# ...Business Objectives (BO)...
#
# -Détecter le cancer du sein le plus tôt possible
#
# -Aider les médecins à prendre des décisions plus rapides et plus précises
#
# -Gagner du temps et réduire les tests inutiles
#
# -Prioriser les patients qui nécessitent une attention urgente
#
# ...Data Science Objectives (DSO)...
#
# -Créer un modèle pour prédire si une tumeur est bénigne ou maligne
#
# -Développer un outil d’aide à la décision fiable et précis
#
# -Identifier les caractéristiques les plus importantes pour le diagnostic
#
# -Classer les patients selon leur probabilité d’avoir une tumeur maligne

# %% [markdown]
#  Phase 2: Data Understanding

# %% [markdown]
# **Interpretation:** 👉

# %% [markdown]
# **Interpretation:** 👉

# %% [markdown]
# **Interpretation:** 👉

# %% [markdown]
#  Phase 3: Data Preparation

# %% [markdown]
#  Phase 4: Modeling

# %% [markdown]
#  Phase 5: Evaluation

# %% [markdown]
# **Interpretation:** 👉

# %% [markdown]
#  Phase 6: Deployment
